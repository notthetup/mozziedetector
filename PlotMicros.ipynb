# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas
pylab.rcParams['figure.figsize'] = 16, 12

# %%
filename = 'micros.txt';

# %%
outdataFile = open(filename,'r');
outData = outdataFile.readlines();
outData = [int(line.strip()) for line in outData[2:]]
outSeries = pandas.Series(outData)

# %%
plot(outSeries[0:248].diff())

# %%
outSeries[0:248].diff().mean()
# Out:
# 120.09716599190283

# %%
1/(outSeries[0:97].diff().mean()/1000000)
# Out:
# 8301.6257350397791
